# %% [markdown]
# # 2 Structures de données : graphes

# %% [raw]
# # Nom :
# # Prénom :

# %% [markdown]
# Les graphes représentent une grande partie du programme de terminale car nous allons voir beaucoup d'algorithmes concernant les graphes. Dans un premier temps, nous allons découvrir les graphes pour aller jusqu'à ceux qui nous intéressent particulièrement cette année : les arbres binaires. Dans un second temps, nous verrons des algorithmes utilisés avec les  graphes.
# La théorie des graphes a commencé en 1735 avec Leonhard Euler, alors qu'il cherchait à résoudre le problème des sept ponts de Königsberg.

# %% [markdown]
# ## I. Définition

# %% [markdown]
# <p dir="auto" data-sourcepos="13:1-13:190">Un <strong>graphe</strong> est un objet mathématique très simple avec lequel on peut faire des choses extrêmement compliquées. Il est constitué de <strong>sommets</strong> reliés par des <strong>arêtes</strong> (ou liens).</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="15:1-15:355">Si les arêtes sont fléchées, on les appelle <strong>arcs</strong> et on parle de <strong>graphe orienté</strong> ; sinon on parle de <strong>graphe non-orienté</strong>. Dans un graphe orienté, on appelle <em>prédécesseur</em> d'un sommet, les sommets qui pointent vers lui. On appelle <em>successeur</em> d'un sommet, les sommets vers lesquels il pointe (<span data-math-style="inline"><span class="katex"><span class="katex-mathml"><math xmlns="http://www.w3.org/1998/Math/MathML"><semantics><mrow><mi>p</mi><mi>r</mi><mover accent="true"><mi>e</mi><mo>ˊ</mo></mover><mi>d</mi><mover accent="true"><mi>e</mi><mo>ˊ</mo></mover><mi>c</mi><mi>e</mi><mi>s</mi><mi>s</mi><mi>e</mi><mi>u</mi><mi>r</mi><mo>→</mo><mi>s</mi><mi>u</mi><mi>c</mi><mi>c</mi><mi>e</mi><mi>s</mi><mi>s</mi><mi>e</mi><mi>u</mi><mi>r</mi></mrow><annotation encoding="application/x-tex">prédécesseur  \rightarrow successeur</annotation></semantics></math></span><span class="katex-html" aria-hidden="true"><span class="base"><span class="strut" style="height:0.8888799999999999em;vertical-align:-0.19444em;"></span><span class="mord mathnormal">p</span><span class="mord mathnormal" style="margin-right:0.02778em;">r</span><span class="mord accent"><span class="vlist-t"><span class="vlist-r"><span class="vlist" style="height:0.69444em;"><span style="top:-3em;"><span class="pstrut" style="height:3em;"></span><span class="mord mathnormal">e</span></span><span style="top:-3em;"><span class="pstrut" style="height:3em;"></span><span class="accent-body" style="left:-0.19444em;"><span class="mord">ˊ</span></span></span></span></span></span></span><span class="mord mathnormal">d</span><span class="mord accent"><span class="vlist-t"><span class="vlist-r"><span class="vlist" style="height:0.69444em;"><span style="top:-3em;"><span class="pstrut" style="height:3em;"></span><span class="mord mathnormal">e</span></span><span style="top:-3em;"><span class="pstrut" style="height:3em;"></span><span class="accent-body" style="left:-0.19444em;"><span class="mord">ˊ</span></span></span></span></span></span></span><span class="mord mathnormal">cesse</span><span class="mord mathnormal">u</span><span class="mord mathnormal" style="margin-right:0.02778em;">r</span><span class="mspace" style="margin-right:0.2777777777777778em;"></span><span class="mrel">→</span><span class="mspace" style="margin-right:0.2777777777777778em;"></span></span><span class="base"><span class="strut" style="height:0.43056em;vertical-align:0em;"></span><span class="mord mathnormal">s</span><span class="mord mathnormal">u</span><span class="mord mathnormal">ccesse</span><span class="mord mathnormal">u</span><span class="mord mathnormal" style="margin-right:0.02778em;">r</span></span></span></span></span>).</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="17:1-17:166">Un graphe est une structure dite <strong>relationnelle</strong>. Un graphe peut représenter un réseau social, des liens d'amitié, un réseau routier, un réseau informatique...</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="19:1-19:125">​	<strong>1)</strong> Pour le graphe ci-dessous, dire s'il est orienté ou non, donner le nombre de sommets et le nombre d'arêtes/arcs.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q1.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="23:1-23:125">​	<strong>2)</strong> Pour le graphe ci-dessous, dire s'il est orienté ou non, donner le nombre de sommets et le nombre d'arêtes/arcs.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q2.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="27:1-27:168">On utilisera parfois des graphes <strong>pondérés</strong> pour représenter par exemple des distances sur une carte. Dans un tel graphe, les arêtes sont associées à un poids :</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/pondere.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="31:1-31:125">​	<strong>3)</strong> Autre que les distances sur un graphe de réseau routier, que peut permettre de représenter un graphe pondéré ?</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="33:1-33:97">On dit qu'un graphe est <strong>complet</strong> si ses sommets sont tous reliés deux à deux par une arête.</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="35:1-35:67">​	<strong>4)</strong> Parmi les graphes suivants, dire lesquels sont complets.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/complet1.png)

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/complet2.png)

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/complet3.png)

# %% [markdown]
# https://fr.wikipedia.org/wiki/Graphe_complet

# %% [markdown]
# ## II. Python, networkx et pyplot

# %%
# Importer les modules nécessaires # networkx et pyplot
import networkx as nx
from matplotlib import pyplot
# -----------------------------------------------------

G=nx.Graph()  # créer un nouveau graphe

print("import de networkx et de matplotlib")

# %%
# Ajout des arêtes
G.add_edge("Gabriel","Jean")  # Ajout d'une arête entre "Gabriel" et "Jean"
G.add_edge("Jean","Mathis")  # Ajout d'une arête entre "Jean et "Mathis"
G.add_edge("Mathis","Nolan")  # Ajout d'une arête entre "Mathis" et "Nolan"
G.add_edge("Jean","Nolan")  # Ajout d'une arête entre "Jean" et "Nolan"
G.add_edge("Gabriel","Nolan")  # Ajout d'une arête entre "Gabriel" et "Nolan"
G.add_edge("Gabriel","Lou")  # Ajout d'une arête entre "Gabriel" et "Lou"
G.add_edge("Lou","Chloé")  # Ajout d'une arête entre "Lou" et "Chloé"
G.add_edge("Lou","Enola")  # Ajout d'une arête entre "Lou" et "Enola"
G.add_edge("Gabriel","Enola")  # Ajout d'une arête entre "Gabriel" et "Enola"

print(str(G.number_of_edges()) + " personnes sont ajoutées")

# %%
# Dessiner le graphe
nx.draw(G, with_labels=True, font_weight='bold')
pyplot.show()

# %% [markdown]
# **Chaîne** : Dans un graphe, une chaîne reliant un sommet x à un sommet y est définie par une suite finie d'arêtes consécutives, reliant x à y.
# Exemple : Dans le graphe donné ci-dessus, Mathis - Jean - Gabriel - Lou - Chloé est une chaîne de 4 arêtes (M-J-G-L-C)

# %%
dico_de_paires_de_plus_cours_chemins = dict(nx.all_pairs_shortest_path(G))
dico_de_paires_de_plus_cours_chemins["Mathis"]["Chloé"]

# %% [markdown]
# **Distance entre 2 sommets** : La distance entre deux sommets d'un graphe est le nombre minimum d'arêtes d'une chaîne allant de l'un à l'autre.
# Exemple : La distance entre le sommet Mathis et le sommet Chloé est de 4 (chaîne M-J-G-L-C).

# %%
dico_de_distances_apairees = dict(nx.all_pairs_shortest_path_length(G))
dico_de_distances_apairees["Mathis"]["Chloé"]

# %% [markdown]
# **Écartement** : L'écartement d'un sommet est la distance maximale existant entre ce sommet et les autres sommets du graphe.
#
# **Centre** : On appelle centre d'un graphe, le sommet d'écartement minimal (le centre n'est pas nécessairement unique).
# Exemple: Gabriel est le centre du graphe car c'est le sommet le plus proche de tous les autres

# %%
print(f"Centre du graphe : {nx.center(G)}")

# %% [markdown]
# **Rayon** : On appelle rayon d'un graphe G, l'écartement d'un centre de G.
# Exemple : Gabriel est le centre du graphe, nous pouvons donc dire que le rayon du graphe est la distance entre Mathis et lui ou entre Chloé et lui (2 arêtes).

# %%
dico_de_distances_apairees = dict(nx.all_pairs_shortest_path_length(G))
dico_de_distances_apairees["Gabriel"]["Chloé"]

# %%
dico_de_distances_apairees["Gabriel"]["Mathis"]

# %% [markdown]
# **Diamètre** : On appelle diamètre d'un graphe G, la distance maximale entre deux sommets du graphe G.
# Exemple : Dans le graphe la distance maximale entre 2 sommets est de 4, nous pouvons donc dire que le diamètre du graphe est de 4 de "Mathis" à "Chloé"

# %%
# Afficher des informations sur ce graphe :
print(f"Nombre de sommets : {G.number_of_nodes()}")
print(f"Nombre d'arêtes : {G.number_of_edges()}")
print(f"Centre du graphe : {nx.center(G)}")
print(f"Diamètre du graphe : {nx.diameter(G)}")

# %% [markdown]
# <b>Autres graphes: <i>il sera peut-être necessaire de relancer le noyau <u>entre chaque graphe.

# %%
# Exemple de graphe orienté
import networkx as nx
import matplotlib.pyplot as plt

G2 = nx.DiGraph()

G2.add_edge("A", "B")
G2.add_edge("A", "C")
G2.add_edge("B", "C")

nx.draw(G2, with_labels=True, arrows=True)
plt.show()

# %%
# exemple de graphe pondéré
import networkx as nx
import matplotlib.pyplot as plt

G3 = nx.Graph()

G3.add_edge("A", "B", weight=5)
G3.add_edge("A", "C", weight=2)
G3.add_edge("B", "C", weight=8)

pos = nx.spring_layout(G3)

nx.draw(G3, pos, with_labels=True)

labels = nx.get_edge_attributes(G3, "weight")
nx.draw_networkx_edge_labels(G3, pos, edge_labels=labels)

plt.show()

# %%
# exemple de graphe orienté et pondéré
import networkx as nx
import matplotlib.pyplot as plt

G4 = nx.DiGraph()

G4.add_edge("A", "B", weight=5)
G4.add_edge("A", "C", weight=2)
G4.add_edge("B", "C", weight=8)

pos = nx.spring_layout(G4)

nx.draw(G4, pos, with_labels=True, arrows=True)

labels = nx.get_edge_attributes(G4, "weight")
nx.draw_networkx_edge_labels(G4, pos, edge_labels=labels)

plt.show()

# %% [markdown]
# ## III. Représentation

# %% [markdown]
# Nous avons utilisé intuitivement une représentation visuelle d'un graphe. Mais nous aurions pû utiliser une description textuelle d'un graphe. Par exemple pour celui de la question 2 :

# %% [markdown]
# <ul dir="auto" data-sourcepos="43:1-48:0">
# <li data-sourcepos="43:1-43:21">A est relié à E ;</li>
# <li data-sourcepos="44:1-44:29">B est relié à C, D et E ;</li>
# <li data-sourcepos="45:1-45:29">C est relié à B, D et E ;</li>
# <li data-sourcepos="46:1-46:26">D est relié à C et B ;</li>
# <li data-sourcepos="47:1-48:0">E est relié à A, B et C.</li>
# </ul>

# %% [markdown]
# <p dir="auto" data-sourcepos="49:1-51:42">​	<strong>5)</strong> Construisez un graphe de réseau social à partir des informations suivantes :
# ​	Tom est ami avec Eve et Max. Eve est ami avec Tom et Sam. Sam est ami avec Eve, Camille et Dean. Dean est ami avec Sam, Camille et Max. Max est ami avec Tom, Dean et Camille. Camille est ami avec Sam, Dean et Max.
# ​	Le graphe est-il orienté ? Pourquoi ?</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="53:1-55:42">​	<strong>6)</strong> Construisez un graphe de réseau social à partir des informations suivantes :
# ​	Audrey est abonné à Ben et Ethan. Ben est abonné à Charles. Charles est abonné à Ben, Karima et Tam. Tam est abonné à Karima et Ethan. Ethan est abonné à Audrey et Karima.
# ​	Le graphe est-il orienté ? Pourquoi ?</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="57:1-59:47">​	<strong>7)</strong> Construisez un graphe de réseau routier à partir des informations suivantes :
# ​	Calais est situé à 109km de Lille, à 158km d'Amiens et à 42km de Dunkerque. Amiens est situé à 198km de Dunkerque et à 141km de Lille. Lille est situé à 76km de Dunkerque.
# ​	Quelle est la particularité de ce graphe ?</p>

# %% [markdown]
# # III. Implémentations

# %% [markdown]
# On parle d'implémentation lorsqu'il s'agit de « représenter » un graphe dans un système informatique. Même si nous ne verrons pas directement comment on implémente un graphe en Python nous allons parler des deux principales implémentations d'un  graphe.

# %% [markdown]
# ## 1. Matrice d'adjacence

# %% [markdown]
# Une matrice n'est qu'un tableau à double entrée :

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/matrice.png)

# %% [markdown]
# Nous avons ci-dessus une matrice à 3 lignes et 4 colonnes. En mathématiques on utilise les matrices pour effectuer des calculs,  nous les utiliserons ici simplement comme des tableaux à deux dimensions.

# %% [markdown]
# <p dir="auto" data-sourcepos="75:1-75:537">Une matrice d'adjacence est une matrice carrée (même nombre de lignes que de colonnes) où chaque ligne et chaque colonne représentent un sommet. Pour un graphe non-orienté on mettra un « 1 » sur la case <code>[i][j]</code> s'il y a une arête entre le sommet i et le sommet j, et un « 0 » sinon. Pour un graphe orienté on mettra un « 1 » sur la case <code>[i][j]</code> s'il y a une arête du sommet i vers le sommet j, et un « 0 » sinon. Pour un graphe pondéré on mettra sur la case <code>[i][j]</code> le poids du lien entre le sommet i et le sommet j.</p>

# %% [markdown]
# <p dir="auto" data-sourcepos="77:1-77:62">​	<strong>8)</strong> Donnez la matrice d'adjacence du graphe ci-dessous.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q2.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="81:1-81:62">​	<strong>9)</strong> Donnez la matrice d'adjacence du graphe ci-dessous.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q1.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="85:1-85:63">​	<strong>10)</strong> Donnez la matrice d'adjacence du graphe ci-dessous.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/pondere.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="89:1-92:29">​	<strong>11)</strong> Soit la matrice d'adjacence d'un graphe G composé des sommets A, B, C, D  :
# ​	<img class="fit-picture"
#      src="https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/matrice_adj.png"
#      alt="img">
# ​	Le graphe G est-il orienté ou non-orienté ? Justifiez votre réponse.
# ​	Représentez ce graphe G.</p>

# %% [markdown]
# ## 2. Liste d'adjacence

# %% [markdown]
# Pour un graphe non orienté, une liste d'adjacence associe à chaque sommet la liste de ses voisins. Par exemple, pour le graphe ci-dessous :

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/adjacence.png)

# %% [markdown]
# La liste d'adjacence serait :

# %% [markdown]
# <ul dir="auto" data-sourcepos="102:1-107:0">
# <li data-sourcepos="102:1-102:19">A → [B, C, E] ;</li>
# <li data-sourcepos="103:1-103:13">B → [A] ;</li>
# <li data-sourcepos="104:1-104:16">C → [A, D] ;</li>
# <li data-sourcepos="105:1-105:16">D → [C, E] ;</li>
# <li data-sourcepos="106:1-107:0">E → [A, D].</li>
# </ul>

# %% [markdown]
# Pour un graphe orienté, une liste d'adjacence associe à chaque sommet la liste de ses successeurs, c'est à dire les sommets vers lesquels il pointe. Il est également possible de faire une liste d'adjacence des prédécesseurs, ou même les deux pour des raisons de symétrie.

# %% [markdown]
# <p dir="auto" data-sourcepos="110:1-110:61">​	<strong>12)</strong> Donnez la liste d'adjacence du graphe ci-dessous.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q2.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="114:1-114:77">​	<strong>13)</strong> Donnez la liste d'adjacence des successeurs du graphe ci-dessous.</p>

# %% [markdown]
# ![img](https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q1.png)

# %% [markdown]
# <p dir="auto" data-sourcepos="118:1-118:83">​	<strong>14)</strong> Représentez le graphe correspondant à la liste d'adjacence suivante :</p>

# %% [markdown]
# <ul dir="auto" data-sourcepos="119:2-124:0">
# <li data-sourcepos="119:2-119:14">A → [B] ;</li>
# <li data-sourcepos="120:2-120:23">B → [A, C, D, E] ;</li>
# <li data-sourcepos="121:2-121:12">C → [];</li>
# <li data-sourcepos="122:2-122:17">D → [A, C] ;</li>
# <li data-sourcepos="123:2-124:0">E → [B, C, D].</li>
# </ul>

# %% [markdown]
# <h3 dir="auto" data-sourcepos="125:1-125:30">
# <a aria-hidden="true" href="#3-choix-dimpl%C3%A9mentation" class="anchor" id="user-content-3-choix-dimplémentation"></a>3. Choix d'implémentation</h3>

# %% [markdown]
# On utilisera une matrice d'adjacence dans le cas d'un graphe avec beaucoup de liens (on parle de graphe dense) et une liste d'adjacence dans le cas contraire. Cela permettera de gagner de la mémoire.
# Le choix peut aussi dépendre de l'utilité du graphe. En fonction de l'algorithme utilisé, on pourra préférer une implémentation à l'autre.

# %% [markdown]
# <p dir="auto" data-sourcepos="131:1-131:95">​	<strong>15)</strong> Donnez la matrice d'adjacence du graphe dont la liste d'adjacence est la suivante :</p>

# %% [markdown]
# <ul dir="auto" data-sourcepos="133:2-140:0">
# <li data-sourcepos="133:2-134:0">
# <p data-sourcepos="133:4-133:17">A → [B, C] ;</p>
# </li>
# <li data-sourcepos="135:2-136:0">
# <p data-sourcepos="135:4-135:14">B → [C] ;</p>
# </li>
# <li data-sourcepos="137:2-138:0">
# <p data-sourcepos="137:4-137:13">C → [B];</p>
# </li>
# <li data-sourcepos="139:2-140:0">
# <p data-sourcepos="139:4-139:17">D → [B, C] ;</p>
# </li>
# </ul>

# %% [markdown]
# <p dir="auto" data-sourcepos="141:1-142:22">​	<strong>16)</strong> Donnez la liste d'adjacence du graphe dont la matrice d'adjacence est la suivante :
# <a rel="noopener noreferrer" href="https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q16.png" class="no-attachment-icon"><img class="js-lazy-loaded qa-js-lazy-loaded" decoding="async" alt="q16" src="https://framagit.org/JB_info/nsi_tale/-/raw/master/structures_de_donnees/img/q16.png" loading="lazy"></a></p>

# %% [markdown]
# ## IV. Propriétés

# %% [markdown]
# Les propriétés les plus communes pour parler d'un graphe sont les suivantes :

# %% [markdown]
# <ul dir="auto" data-sourcepos="150:1-154:0">
# <li data-sourcepos="150:1-150:71">une <strong>chaîne</strong> (ou <em>chemin</em>) est une suite d'arêtes consécutives ;</li>
# <li data-sourcepos="151:1-151:68">la longueur d'une chaîne est le nombre d'arêtes qui la compose ;</li>
# <li data-sourcepos="152:1-152:106">la <strong>distance</strong> entre deux sommets est la longueur de la chaîne la plus courte entre ces deux sommets ;</li>
# <li data-sourcepos="153:1-154:0">un <strong>cycle</strong> est une chaîne fermée, c'est à dire qui commence et termine par le même sommet.</li>
# </ul>

# %% [markdown]
# <p dir="auto" data-sourcepos="155:1-155:103">​	<strong>17)</strong> Pour le graphe ci-dessous, trouvez deux cycles. Donnez également la distance entre A et D.</p>

# %% [markdown]
# ![img](https://kxs.fr/cours/graphes/img/graphe_non_oriente.svg)

# %% [markdown]
# Nous verrons les algorithmes qui permettent de rechercher une chaîne, de repérer un cycle et de calculer une distance plus tard dans l'année.
