# %% [markdown]
# <h1>Projet N°1

# %% [raw]
# Nom:
# Prénom:

# %% [markdown]
# Ce projet consiste à utiliser ce notebook pour tester les codes que vous allez rencontrer tout au long du cours sur Python de ce début d'année.

# %%
#Types de nombres

# %%
#Variables

# %%
#Types de base et variables

# %%
#Opérateurs

# %%
#Chaînes

# %%
#Structures conditionnelles

# %%
#Boucles bornées

# %%
#Boucles non bornées

# %%
#Fonctions

# %%
#Modules

# %%
#Bonnes pratiques

# %%
#Résumé des bonnes pratiques

# %%
#Mes tests

# %%
#Mes tests

# %%
#Mes tests

# %% [markdown]
# <b><i>Laisser ce projet dans votre dossier travail pour évaluation.

# %% [raw]
# -  10 points si tous les sujets sont traités.
# -  5 points si tout est bon.
# - 5 points si c'est propre et beau à regarder.
# (ajout de cellules, de titres, de présentation en html ou markdown)
# En cas d'absence au cours le signaler au cours suivant pour récuperer le contenu à la maison.
